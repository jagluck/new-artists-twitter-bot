# %%
import boto
import boto.s3.connection
import boto3
import tweepy as tweepy
import requests as requests
import json
import re
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from rake_nltk import Rake
import math
from random import randint
from time import sleep

keys={}
with open("/Users/jagluck/Documents/GitHub/new-artists-twitter-bot/keys.json","r") as f:
    keys = json.loads(f.read())
    
# Consumer keys and access tokens, used for OAuth
tw_consumer_key = keys["tw_consumer_key"]
tw_consumer_secret = keys["tw_consumer_secret"]
tw_access_token = keys["tw_access_token"]
tw_access_token_secret = keys["tw_access_token_secret"]
db_access_key = keys["db_access_key"]
db_secret_key = keys["db_secret_key"]
setlist_api_key = keys['setlist_api_key']

# bucket_name = 'trump-last-tweets' # replace with your bucket name
# object_key = 'tweets.json' # replace with your object key

# emojis={}
# with open("/Users/jagluck/Documents/GitHub/new-artists-twitter-bot/artists.json","r") as f:
#     emojis = json.loads(f.read())

 
# OAuth process, using the keys and tokens
# auth = tweepy.OAuthHandler(tw_consumer_key, tw_consumer_secret)
# auth.set_access_token(tw_access_token, tw_access_token_secret)
 
# Creation of the actual interface, using authentication
# api = tweepy.API(auth)

# s3 = boto3.resource('s3',
#          aws_access_key_id=db_access_key,
#          aws_secret_access_key=db_secret_key)
# my_bucket = s3.Bucket(bucket_name)

# def sendTweet(content):
#     api.update_status(content)
    
# def buildTweet(text, link):
#     tweet = text + " " + link
#     sendTweet(tweet)

# def readDatabase():

#     with open('tweets.json','wb') as data:
#         my_bucket.download_fileobj(object_key, data)

#     old_tweets={}
#     with open("C:\\Users\\jagluck\\Documents\\Github\\twitter-user-emoji-bot\\tweets.json","r") as f:
#         text = f.read()
    
#     old_tweets = json.loads(text)

#     # return old_tweets['tweets']
#     return old_tweets

# def updateDatabase(json_data):

#     with open('tweets.json', 'wb') as outfile:
#         outfile.write(json_data)

#     with open('tweets.json', 'rb') as data:
#         my_bucket.upload_fileobj(data, object_key)

def sendReqSet(num, id):
    
    url = 'https://api.setlist.fm/rest/1.0/venue/' + str(id) + '/setlists/?p=' + str(num)
    headers = {'Accept': 'application/json', 'x-api-key': setlist_api_key}
    r = ''
    
    while r == '':
        # try to get ID
        try:
            r = requests.get(url, headers=headers)
        # if max tries exceed, sleep and try again
        except:
            time.sleep(5)
            
    page = r.json()
    return page

# get the artists out of a response from the api
def getVenueArtists(venueResp):
    artistsFromPage = set()
    for artistSet in venueResp['setlist']:
        artistsFromPage = artistsFromPage.union([artistSet['artist']['name']])
    return artistsFromPage

def getAllArtistsFromVenue(venueId):
    
    artistsFromVenue = set()
    page = 1
    
    # get first result page
    venueResp = sendReqSet(page, venueId)
    
    # pull responses untl you get all of them
    while('setlist' in venueResp):
        
        # sleep random time
        sleep((randint(500,1000)/1000))
        
        # get results from page
        artistsFromPage = getVenueArtists(venueResp)
        artistsFromVenue = artistsFromVenue.union(artistsFromPage)
        
        # set up next loop
        page = page + 1
        venueResp = sendReqSet(page, venueId)
    
    return artistsFromVenue

def getAllArtistsFromCity(venueIds):
    
    artistsFromCity = set()
    
    for venueId in venueIds:
        print(venueId)
        artistsFromVenue = getAllArtistsFromVenue(venueId)
        artistsFromCity = artistsFromCity.union(artistsFromVenue)
    
    return artistsFrom
    

def getCurrentArtists():
    return []


def runBot():
#     old_tweets = readDatabase()
    current = getCurrentArtists()
#     new_tweets = current['tweets']
#     links = current['links']

#     for new in new_tweets:
#         if new not in old_tweets:
#             translated = translateText(new)
#             tweet_id = links[new]
#             print(translated)
            #sendTweet(translated + " " + "https://twitter.com/realDonaldTrump/status/" + str(tweet_id))

#     json_data = json.dumps(new_tweets)
#     updateDatabase(json_data.encode('utf-8'))


# runBot()

# %%
venueInfo = {
    "3d635a7" : "9:30 Club",
    "1bd635f4" : "Black Cat",
    "3bd5ecd0" : "Songbyrd",
    "7bd29e24" : "The Anthem",
    "43d63bff" : "Rock and Roll Hotel",
    "3bd2b05c" : "Capital One Areana",
    "33d55869" : "The Howard Theatre",
    "3bd6c8a0" : "Comet Ping Pong",
    "43d74f6f" : "The Fillmore",
    "5bd54bc8" : "U Street",
    "23d6d063" : "DC9",
    "33d2f00d" : "Union Stage",
    "43d48323" : "Echostage",
    "4bd4eb4e" : "Gypsy Sallys"
}

venueIds = ['3d635a7']
artistsFromCity = getAllArtistsFromCity(venueInfo.keys())
# Out:
# 3d635a7
# 1bd635f4
# 3bd5ecd0
# 7bd29e24
# 43d63bff
# 3bd2b05c
# 33d55869
# 3bd6c8a0
# 43d74f6f
# 5bd54bc8
# 23d6d063
# 33d2f00d
# 43d48323
# 4bd4eb4e

# %%
print(len(artistsFromCity))
# Out:
# 5786

# %%
print(artistsFromCity)
# Out:
# {'No Doubt', 'DNA', 'Hail Mary Mallon', 'Soaked Oats', 'The Temptations', 'Tommy Keene', 'Gigamesh', 'The Academy Is…', 'The Jon Spencer Blues Explosion', 'Ruby & The Romantics', 'B’z', 'Kevin Devine', 'LVL UP', 'Powermad', 'Hypocrisy', 'Yngwie J. Malmsteen', 'Ørjan Nilsen', 'Little Richard', 'Lionize', 'How to Destroy Angels', 'Smith Westerns', 'Jo Mersa Marley', 'King Krule', 'Tauren Wells', 'Lifehouse', 'Exhumed', 'Andy Shauf', 'Stone Horses', 'The Wrens', 'A Sunny Day in Glasgow', 'Julian Lage Trio', 'The Weepies', 'Two Inch Astronaut', 'Sick Puppies', 'AJR', 'Hein Cooper', 'Dio', 'Kool Keith', 'Birdy', 'The Platters', 'Phoebe Bridgers', 'Thy Art Is Murder', 'John K. Samson', 'Gauche', 'The Heavy', 'Billy Raffoul', 'Jenny Lewis', 'Serena Ryder', 'Matt Simons', 'The Obsessed', 'Neon Trees', 'Full Blown Chaos', 'Pork Tornado', 'Granger Smith', 'The Books', 'The Chapin Sisters', 'Cows', 'Death Cab for Cutie', 'Pentagram', 'Warbringer', 'Off With Their Heads', 'La Femme', 'Sara Evans', 'Deakin', 'Vampire Weekend', 'Dawn Richard', 'Iceage', 'Motörhead', 'Mad at Gravity', 'Jack White', 'KOLARS', 'Unicorn Kid', 'Pavement', 'Suckers', 'Jared Hart', 'Runaway June', 'Golden Smog', 'Chelsea Cutler', 'Digable Planets', 'PUP', 'RJD2', 'Big Something', 'Nine Lashes', 'Sturgill Simpson', 'Phoebe Ryan', 'Hangar 18', 'Valentino Khan', 'Ultravox', 'As It Is', 'Jimmy Gnecco', 'Blackbird Blackbird', 'Blonde Redhead', 'Magnolia Electric Co.', "The F.U.'s", 'The Boxer Rebellion', 'Kaki King', 'Cancer Bats', 'Evanescence', 'Truckfighters', 'Scratch Acid', 'Ilsa', 'Lee Dorsey', 'Plague Vendor', 'Battle Beast', '.moneen.', 'Sons of Bill', 'Mayer Hawthorne & The Country', 'Bo Deans', "Darwin's Waiting Room", 'Thirdstory', 'Mouse on Mars', 'Marginal Man', 'Nancy Sinatra', 'Land of Talk', 'David Mead', 'Street Dogs', 'Holiday Sidewinder', 'David Lee Roth', 'Lush', 'Low', 'The Fixx', 'NF', 'Tyler Childers', 'The Derek Trucks Band', 'Sinéad O’Connor', 'LAPêCHE', 'Roadkill Ghost Choir', 'Born Cages', 'The Mermen', 'Gordi', 'Ivy', 'The Folksmen', 'Robin Trower', 'Eisley', 'Neurosis', 'Eli Cook', 'Black Breath', 'The Temper Trap', "Joe Russo's Almost Dead", 'Spirit Caravan', 'Superet', 'The Safety Fire', 'Jawbox', 'Motion City Soundtrack', 'ISLAND', 'The Dead Ships', 'MONAKR', 'Letters to Cleo', 'Victor Wooten Trio', 'Decapitated', 'The Shadows of Knight', 'Placebo', 'Jimmy Eat World', 'Bill Callahan', 'J. Robbins', 'Kelsea Ballerini', 'Mägo de Oz', 'Gas', 'Lifetime', 'The Grapes of Wrath', 'Summer Camp', 'Kelis', 'The Album Leaf', 'Chastity Belt', 'James Blunt', 'Vagabon', 'AURORA', 'Metro Station', 'Dot Allison', 'Elastica', 'Stephen Kellogg and The Sixers', 'Robert & Johnny', 'Paul Cauthen', 'Dethklok', 'Wallows', 'Oscar', 'Rolling Blackouts Coastal Fever', 'Hooray for Earth', 'Eternal Summers', 'Benjamin Gibbard', 'Peter Murphy', 'Scotty McCreery', 'Kid Koala', 'Weekend', 'The Dictators', 'The Specials', 'Martin Garrix', 'Trans‐Siberian Orchestra', 'Late of the Pier', 'Relient K', 'Chelsea Grin', 'Shakira', 'Angel Du$t', 'Milagres', 'Holy Fuck', 'Clara Smith', 'VAMPS', 'The Big Wu', 'Quix*O*Tic', 'Snot', 'Unrest', 'Memphis', 'The Menzingers', 'Neil Finn', 'Robert Palmer', 'Clap Your Hands Say Yeah', 'Nick 13', 'Madison Cunningham', 'Streetlight Manifesto', 'The Cynics', 'TV on the Radio', 'Meg Myers', 'Iron & Wine and Calexico', 'The Walkmen', 'Fever Ray', 'DJ Freestyle Steve', 'Richard Buckner', 'Amen', 'My Morning Jacket', 'Royal Thunder', 'Matchbox Twenty', 'Brantley Gilbert', 'The Dickies', 'M.O.D.', 'Crash Kings', 'Dungen', 'Ganja White Night', 'Quintus', 'Panda Bear', 'KEN mode', 'Pogo', 'The Romantics', 'Vanna', 'Dionne Warwick', 'New Politics', 'Delain', 'Love Tractor', 'Sea Wolf', 'lil aaron', 'Depeche Mode', 'The Jealous Sound', 'Skinny Puppy', 'Ian McCulloch', 'Pig Destroyer', 'Obscura', 'The Infamous Stringdusters', 'Kehlani', 'Justin Jones & The Driving Rain', 'Glorietta', 'Mike Gordon', 'Public Image Ltd', 'Kaskade', 'Obliterations', 'YA ...

# %%
dcartists = {"artists" : list(artistsFromCity)}
with open('dcartists.json', 'w') as fp:
    json.dump(dcartists, fp)
